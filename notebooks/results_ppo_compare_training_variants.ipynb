# %%
import sys
sys.path.append('..')

# %%
from hearts_ai.rl.results import (
    load_training_results,
    PlotMakerPlaying,
)

# %%
def log_path(name: str) -> str:
    return f'../output/logs/{name}'


def out_path(name: str) -> str:
    return f'../output/plots/ppo_playing_compare_training_variants/{name}'

# %%
r_play = load_training_results(log_path=log_path('ppo_playing_compare_stages_setups/every_192x1000'))
r_both = load_training_results(log_path=log_path('ppo_both_agents/play'))

# %% [markdown]
# # Training of 'both' variant

# %%
plot_maker_both = PlotMakerPlaying(r_both, folder=out_path('both'), show=True)
plot_maker_both.plot_training()

# %% [markdown]
# # Comparison

# %%
plot_maker_compare = PlotMakerPlaying(
    results={
        'Only playing agent': r_play,
        'Play + card pass': r_both,
    },
    folder=out_path('comparison'),
    show=True,
)

# %%
plot_maker_compare.plot_eval()
