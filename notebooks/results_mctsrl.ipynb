# %%
import sys
sys.path.append('..')

# %%
from hearts_ai.rl.results import (
    load_training_results, 
    PlotMakerPlaying,
    print_best_eval_run,
)

# %%
def log_path(name: str) -> str:
    return f'../output/logs/mctsrl/{name}'


def out_path(name: str) -> str:
    return f'../output/plots/mctsrl/{name}'

# %%
r_mctsrl_play_ppo_pass = load_training_results(log_path=log_path('mctsrl_play_ppo_pass'))

# %% [markdown]
# # Both MCTS+RL

# %%
plot_maker_mctsrl = PlotMakerPlaying(r_mctsrl_play_ppo_pass, folder=out_path('mctsrl_play_ppo_pass'), show=True)
plot_maker_mctsrl.plot_training()

# %%
plot_maker_mctsrl.plot_eval('random')

# %%
plot_maker_mctsrl.plot_eval('rule_based')

# %% [markdown]
# Check which run was the best

# %%
print_best_eval_run(r_mctsrl_play_ppo_pass, 'rule_based')
# Out:
# The best evaluation occurred during 'run_3' (episode_reward=-8.92 +/- 10.32)
